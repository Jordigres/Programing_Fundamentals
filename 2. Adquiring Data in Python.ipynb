# %% [markdown]
# Programming Fundamentals
# ============================
#
# In this notebook, different data from the web will be obtained using several methods (web API manually, web API libraries and web scrapping).

# %% [markdown]
# ### Exercice 1

# %% [markdown]
# Using the [request](http://docs.python-requests.org/) library, a manually request to an API can be made. For example:
#
# `Response = requests.get ('http://api.postcodes.io/postcodes/E98%201TT')`
#
# When the request is performed, an object is recovered that contains, among other things, the following attributes:**status.code**, **content** and **headers**. Search information about the different **status.code** and complete the https error codes' chart:

# %% [markdown]
# Main http error codes:
# - 200: OK
# - 301: Moved Permanently. The resource has been moved permanently.
# - 400: Bad Request.The server cannot or will not process the request due to an apparent client error (e.g., malformed request syntax)
# - 401: Unauthorized. It appears when authentication is required and it has failed or has not yet been provided
# - 403: Forbidden. The request contained valid data and was understood by the server, but the server is refusing the action.
# - 404: Not found. The requested resource could not be found but may be available in the future.
# - 500: Internal Server Error. A generic error message, given when an unexpected condition was encountered and no more specific message is suitable.
# - 501: The server either does not recognize the request method, or it lacks the ability to fulfilÇl the request. Usually this implies future availability.

# %% [markdown]
# ### Exercice 2

# %% [markdown]
# In this exercice we will try to make a request to 4 different websites using the http protocol's GET. GET is implemented in `requests.get`.
#
# Obtain using `request.get` the content and the status.code of the following websites:
#
# - http://google.com
# - http://wikipedia.org
# - https://mikemai.net/
# - http://google.com/noexisto
#
# For each website show:
# - First 80 characters of the content
# - The `status.code`

# %%
# Import library
import requests

urls = ["http://google.com",
        "http://wikipedia.org",
        "https://mikemai.net",
        "http://google.com/noexisto"]

for u in urls:
    r = requests.get(u)
    print("First characters of: %s" % u)
    print("-"*60)
    try:
        print(r.text.split("content=\"")[1][:60])
    except:
        print("error")
    print("-"*60)
    print("Status code: %d \n" % r.status_code)
# Out:
# First characters of: http://google.com
# ------------------------------------------------------------
# Google.es permite acceder a la información mundial en castel
# ------------------------------------------------------------
# Status code: 200
#
# First characters of: http://wikipedia.org
# ------------------------------------------------------------
# Wikipedia is a free online encyclopedia, created and edited
# ------------------------------------------------------------
# Status code: 200
#
# First characters of: https://mikemai.net
# ------------------------------------------------------------
# error
# ------------------------------------------------------------
# Status code: 406
#
# First characters of: http://google.com/noexisto
# ------------------------------------------------------------
# initial-scale=1, minimum-scale=1, width=device-width">
#   <ti
# ------------------------------------------------------------
# Status code: 404

# %% [markdown]
# ### Exercice 3
# In this exercice we will have fun with cats. *Cat-facts* has the API: https://cat-fact.herokuapp.com. This API has two access points:
#
# - **/facts**
# - **/users**
#
# Each fact is structured in the following way:
#
#
# |    Key    |      Type     |                                              Description                                              |   |   |
# |:---------:|:-------------:|:-----------------------------------------------------------------------------------------------------:|---|---|
# | _id       | ObjectId      | Unique ID for the Fact                                                                                |   |   |
# | _v        | Number        | Version number of the Fact                                                                            |   |   |
# | user      | ObjectId      | ID of the User who added the Fact                                                                     |   |   |
# | text      | String        | The Fact itself                                                                                       |   |   |
# | updatedAt | Timestamp     | Date in which Fact was last modified                                                                  |   |   |
# | sendDate  | Timestamp     | If the Fact is meant for one time use, this is the date that it is used                               |   |   |
# | deleted   | Boolean       | Whether or not the Fact has been deleted (Soft deletes are used)                                      |   |   |
# | source    | String (enum) | Can be 'user' or 'api', indicates who added the fact to the DB                                        |   |   |
# | used      | Boolean       | Whether or not the Fact has been sent by the CatBot. This value is reset each time every Fact is used |   |   |
# | type      | String        | Type of animal the Fact describes (e.g. ‘cat’, ‘dog’, ‘horse’)                                        |   |   |
#
# To obtain the **fact** with id *58e0086f0aac31001185ed02*, we must build the request:
#
# - *https://cat-fact.herokuapp.com/facts/58e0086f0aac31001185ed02*
#
# The resulting object will contain the previous table information in a json format.
#
# a) Make a request, transform the result into a dictionary and show the result of the previous table for a fact with and id *58e0086f0aac31001185ed02*.

# %%
import requests
import json

u = "https://cat-fact.herokuapp.com"
accessPoint = "facts"
factnumber = "58e0086f0aac31001185ed02"

# Create url
f = requests.get('/'.join((u, accessPoint, factnumber)))

# Transform to dictionary
f_dict = json.loads(f.text)
f_dict
# Out:
# {'status': {'verified': True, 'sentCount': 1},
#  'type': 'cat',
#  'deleted': False,
#  '_id': '58e0086f0aac31001185ed02',
#  'user': {'name': {'first': 'Kasimir', 'last': 'Schulz'},
#   'photo': 'https://lh6.googleusercontent.com/-BS_rskGd3kA/AAAAAAAAAAI/AAAAAAAAADg/yAxrX9QabMg/photo.jpg?sz=200',
#   '_id': '58e007480aac31001185ecef'},
#  'text': "Cats can't taste sweetness.",
#  '__v': 0,
#  'source': 'https://www.scientificamerican.com/article/strange-but-true-cats-cannot-taste-sweets/',
#  'updatedAt': '2020-08-29T20:20:03.172Z',
#  'createdAt': '2018-03-16T20:20:03.622Z',
#  'used': True}

# %% [markdown]
# b) For the following *fact ids*:
#
# - *5d38bdab0f1c57001592f156*
# - *5ed11e643c15f700172e3856*
# - *5ef556dff61f300017030d4c*
# - *5d9d4ae168a764001553b388*
#
#
# Obtain the fields *type*, *user*, *user*, *source*, *used*, *text* and print them on this format:
#
# `Type: cat	User: 58e007480aac31001185ecef
# Used: True	Id: 58e0086f0aac31001185ed02
# Source: https://www.scientificamerican.com/article/strange-but-true-cats-cannot-taste-sweets/
# Text: Cats can't taste sweetness.`

# %%
import requests
import json

u = "https://cat-fact.herokuapp.com"
facts = "facts"


factnumbers = ["5d38bdab0f1c57001592f156",
               "5ed11e643c15f700172e3856",
               "5ef556dff61f300017030d4c",
               "5d9d4ae168a764001553b388"]

for fn in factnumbers:
    f = requests.get('/'.join((u, facts, fn)))
    f_dict = json.loads(f.text)
    strformat = "Type: %s\tUser: %s\nUsed: %s\tId: %s\nSource: %s\nText: %s\n\n"
    print(strformat % (f_dict['type'],
                       f_dict['user'],
                       f_dict['used'],
                       f_dict['_id'],
                       f_dict['source'],
                       f_dict['text']))
# Out:
# Type: cat	User: {'name': {'first': 'Alex', 'last': 'Wohlbruck'}, 'photo': 'https://lh3.googleusercontent.com/a-/AOh14GhYgUCf9yFuj-Xt6_X_cDz-5gSusrGde-lerdKqXxA=s50', '_id': '5a9ac18c7478810ea6c06381'}
# Used: False	Id: 5d38bdab0f1c57001592f156
# Source: user
# Text: While some cats love being brushed, others don't take to it naturally. Try to groom your cat in the same spot at the same time of day to create a sense of routine.
#
#
# Type: cat	User: {'name': {'first': 'Luciano', 'last': 'Garrido Sepulveda'}, 'photo': 'https://cat-fact.herokuapp.com/img/res/avatars/user-face.png', '_id': '5ed11e353c15f700172e3855'}
# Used: False	Id: 5ed11e643c15f700172e3856
# Source: user
# Text: Los gatos tienen más huesos que los seres humanos, nos ganan por 24.
#
#
# Type: cat	User: {'name': {'first': 'Andrew', 'last': 'Pobrica'}, 'photo': 'https://cat-fact.herokuapp.com/img/res/avatars/user-face.png', '_id': '5e1a9b981fd6150015fa736f'}
# Used: False	Id: 5ef556dff61f300017030d4c
# Source: user
# Text: Lucy, the oldest cat ever, lived to be 39 years old which is equivalent to 172 cat years.
#
#
# Type: cat	User: {'name': {'first': 'Erick', 'last': 'Vazquez'}, 'photo': 'https://lh3.googleusercontent.com/a-/AAuE7mCeOgVhx8kfhBLuXtJ5Hbr6kx28PsWqy28fimQymA=s50', '_id': '5d9d4a4468a764001553b387'}
# Used: False	Id: 5d9d4ae168a764001553b388
# Source: user
# Text: Cats conserve energy by sleeping for an average of 13 to 14 hours a day.

# %% [markdown]
# ### Exercice 4
#
# In the previous exercices, we have used the request library to manually download the content of an API. However, there are special libraries that facilitate the access to certain APIs but an identification is required.
#
# Use the documentation to obtain the 4 authentification codes required to use the Twitter's API **tweepy**. Using this library, program two functions:
#
# - The first one will authentify the user using the 4 codes obtained in the register.
# - The second one will receive the object `twepy.models.User` and will print:
#     1. Number of tweets of the user
#     2. Number of friends
#     3. Number of followers
#     4. The `Screen_name` and `name` of the first 10 friends with their descriptions.
#
# Execute both functions using the **Space_Station** twitter user.

# %%
import tweepy


def InitUser(username):

    consumer_key = 'cgjQlNPlYdY6xCx54p9aIqw2p'
    consumer_secret = 'okrnv66Q96Hk7S4vvtU72OAgG6ilDbTUgFnARZx9dxfHqDayNV'
    access_token = '1292698694794477569-KjCUFsidhoZM9mKp2PVZHLGm6bNykY'
    access_secret = 'c9nYZOVqnon5FV1LlITbIt0lK4aML3tT3UvKXHyNgOgBf'

    #  Initialize interaction with the API
    auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_token, access_secret)
    api = tweepy.API(auth)

    # Obtain user info
    user = api.get_user(username)

    # Return a tuple
    return (user, api)

# %%
def InfoUser(user):
    
    print("Number of followers: {}".format(user.followers_count))
    print("Number of friends: {}".format(user.friends_count))
    print("Number of tweets: {}\n".format(user.statuses_count))
    
    for i, f in enumerate(user.friends()[:10]):
        print("N: %d\tName: %s\tScreenName: %s\tDescription:%s\n" %
              (i+1, f.name, f.screen_name, f.description))

# %%
(user, api) = InitUser("Space_Station")
InfoUser(user)
# Out:
# Number of followers: 4340700
# Number of friends: 218
# Number of tweets: 13918
#
# N: 1	Name: Zebulon Scoville	ScreenName: Explorer_Flight	Description:86th NASA Flight Director. Lucky husband and father. Always looking for a challenge. Tweets are my own, so don't blame NASA.
#
# N: 2	Name: Stephanie Wilson	ScreenName: Astro_Stephanie	Description:
#
# N: 3	Name: Jim Morhard	ScreenName: jmorhard	Description:
#
# N: 4	Name: Bob Cabana	ScreenName: Astro_CabanaBob	Description:Former astronaut and current Center Director of Kennedy Space Center.
#
# N: 5	Name: Sergey Kud-Sverchkov	ScreenName: KudSverchkov	Description:Космонавт Роскосмоса (@Roscosmos) Сергей Кудь-Сверчков
# //
# @Roscosmos cosmonaut Sergey Kud-Sverchkov
#
# N: 6	Name: U.S. Space Command	ScreenName: US_SpaceCom	Description:The OFFICIAL Twitter Page of United States Space Command, the 11th Combatant Command in the Department of Defense. #USSPACECOM
#
# N: 7	Name: Joshua Kutryk	ScreenName: Astro_Kutryk	Description:Canadian Space Agency Astronaut and RCAF Test Pilot.
#
# N: 8	Name: Ivan Vagner	ScreenName: ivan_mks63	Description:Космонавт Роскосмоса (@Roscosmos) Иван Вагнер
# //
# @Roscosmos cosmonaut Ivan Vagner
#
# N: 9	Name: Megan McArthur	ScreenName: Astro_Megan	Description:NASA Astronaut and veteran of Space Shuttle mission STS-125.
#
# N: 10	Name: Jasmin Moghbeli	ScreenName: AstroJaws	Description:Mommy. Marine Attack Helicopter Pilot. Test Pilot. NASA Astronaut. Excited to share my journey!

# %% [markdown]
# ### Exercice 5
#
# [Congreso.es](http://www.congreso.es/) is the Spain's Congress of Deputies website. Inside this [website](https://www.congreso.es/web/guest/hemiciclo), there is a representation of the hemicycle together with each deputy's location,  fotograph, territorial representation and political party.
#
# Use `scrappy` to extract (using an `xpath`) the following information as dictionary. For example:
#
# `{ 'Nombre': 'Carrerons Cano, Juan Antonio', 'Territorio': 'Diputat per Ciudad Real', 'Partido': 'G.P. Popular al Congrés ',' url ':' /wc/htdocs/web/img/diputados/peq/35_14.jpg '} `

# %%
import scrapy
from scrapy.crawler import CrawlerProcess

# Create spider
class deputies_spider(scrapy.Spider):

    # Spider's name
    name = "congreso_spider"

    # url
    start_urls = ["https://www.congreso.es/web/guest/hemiciclo"]
    xpath = ' '
    
    def parse(self, response):
        # Extract the information
        xpath = '//area/@onmouseover'
        for dip in response.xpath(xpath):
            _, iurl, _, _, _, Nom, _, Territori, _, Partit, _, _, _, _, _ = dip.extract().split("'")
            yield {
                'Nombre': Nom.split('(')[0],
                'Territorio': Territori,
                'Partido': Partit,
                'url': iurl
            }

# %%
if __name__ == "__main__":

    # Create Crawler
    process = CrawlerProcess({
        'USER_AGENT': 'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1)',
        'DOWNLOAD_HANDLERS': {'s3': None},
        'LOG_ENABLED': True
    })

    process.crawl(deputies_spider)

    # Start process
    process.start()
# Out:
# 2021-02-08 09:20:49 [scrapy.utils.log] INFO: Scrapy 2.4.1 started (bot: scrapybot)
# 2021-02-08 09:20:49 [scrapy.utils.log] INFO: Versions: lxml 4.6.1.0, libxml2 2.9.10, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 20.3.0, Python 3.8.5 (default, Sep  3 2020, 21:29:08) [MSC v.1916 64 bit (AMD64)], pyOpenSSL 19.1.0 (OpenSSL 1.1.1i  8 Dec 2020), cryptography 3.1.1, Platform Windows-10-10.0.18362-SP0
# 2021-02-08 09:20:49 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2021-02-08 09:20:49 [scrapy.crawler] INFO: Overridden settings:
# {'USER_AGENT': 'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1)'}
# 2021-02-08 09:20:49 [scrapy.extensions.telnet] INFO: Telnet Password: bf15028f27d574ab
# 2021-02-08 09:20:49 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.logstats.LogStats']
# 2021-02-08 09:20:50 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2021-02-08 09:20:50 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2021-02-08 09:20:50 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2021-02-08 09:20:50 [scrapy.core.engine] INFO: Spider opened
# 2021-02-08 09:20:50 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2021-02-08 09:20:50 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2021-02-08 09:20:51 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.congreso.es/web/guest/hemiciclo> (referer: None)
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Batet Lamaña, Meritxell ', 'Territorio': 'Diputada por Barcelona', 'Partido': 'G. P. Mesa del Congreso', 'url': '/docu/imgweb/diputados/215_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Rodríguez Gómez de Celis, Alfonso ', 'Territorio': 'Diputado por Sevilla', 'Partido': 'G. P. Mesa del Congreso', 'url': '/docu/imgweb/diputados/168_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Pastor Julián, Ana María ', 'Territorio': 'Diputada por Madrid', 'Partido': 'G. P. Mesa del Congreso', 'url': '/docu/imgweb/diputados/31_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Elizo Serrano, María Gloria ', 'Territorio': 'Diputada por Madrid', 'Partido': 'G. P. Mesa del Congreso', 'url': '/docu/imgweb/diputados/300_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Gil Lázaro, Ignacio ', 'Territorio': 'Diputado por Valencia/València', 'Partido': 'G. P. Mesa del Congreso', 'url': '/docu/imgweb/diputados/295_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Pisarello Prados, Gerardo ', 'Territorio': 'Diputado por Barcelona', 'Partido': 'G. P. Mesa del Congreso', 'url': '/docu/imgweb/diputados/290_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Hernanz Costa, Sofía ', 'Territorio': 'Diputada por Balears (Illes)', 'Partido': 'G. P. Mesa del Congreso', 'url': '/docu/imgweb/diputados/289_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Sánchez Serna, Javier ', 'Territorio': 'Diputado por Murcia', 'Partido': 'G. P. Mesa del Congreso', 'url': '/docu/imgweb/diputados/67_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Suárez Illana, Adolfo ', 'Territorio': 'Diputado por Madrid', 'Partido': 'G. P. Mesa del Congreso', 'url': '/docu/imgweb/diputados/32_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Sánchez Pérez-Castejón, Pedro ', 'Territorio': 'Diputado por Madrid', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/274_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Calvo Poyato, Carmen ', 'Territorio': 'Diputada por Madrid', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/258_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Iglesias Turrión, Pablo ', 'Territorio': 'Diputado por Madrid', 'Partido': 'G. P. Confederal de Unidas Podemos-En Comú Podem-Galicia en Común', 'url': '/docu/imgweb/diputados/319_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Montero Cuadrado, María Jesús ', 'Territorio': 'Diputada por Sevilla', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/225_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Ábalos Meco, José Luis ', 'Territorio': 'Diputado por Valencia/València', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/267_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Díaz Pérez, Yolanda ', 'Territorio': 'Diputada por Pontevedra', 'Partido': 'G. P. Confederal de Unidas Podemos-En Comú Podem-Galicia en Común', 'url': '/docu/imgweb/diputados/171_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Montero Gil, Irene María ', 'Territorio': 'Diputada por Madrid', 'Partido': 'G. P. Confederal de Unidas Podemos-En Comú Podem-Galicia en Común', 'url': '/docu/imgweb/diputados/329_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Garzón Espinosa, Alberto ', 'Territorio': 'Diputado por Málaga', 'Partido': 'G. P. Confederal de Unidas Podemos-En Comú Podem-Galicia en Común', 'url': '/docu/imgweb/diputados/12_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Calviño Santamaría, Nadia María ', 'Territorio': 'Diputado por ', 'Partido': 'G. P. ', 'url': '/docu/imgweb/diputados/517_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Ribera Rodríguez, Teresa ', 'Territorio': 'Diputado por ', 'Partido': 'G. P. ', 'url': '/docu/imgweb/diputados/502_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Campo Moreno, Juan Carlos ', 'Territorio': 'Diputado por ', 'Partido': 'G. P. ', 'url': '/docu/imgweb/diputados/518_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Robles Fernández, Margarita ', 'Territorio': 'Diputado por ', 'Partido': 'G. P. ', 'url': '/docu/imgweb/diputados/504_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'González Laya, María Aránzazu ', 'Territorio': 'Diputado por ', 'Partido': 'G. P. ', 'url': '/docu/imgweb/diputados/503_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Grande-Marlaska Gómez, Fernando ', 'Territorio': 'Diputado por ', 'Partido': 'G. P. ', 'url': '/docu/imgweb/diputados/509_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Celaá Diéguez, Isabel ', 'Territorio': 'Diputado por ', 'Partido': 'G. P. ', 'url': '/docu/imgweb/diputados/510_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Maroto Illera, Reyes ', 'Territorio': 'Diputado por ', 'Partido': 'G. P. ', 'url': '/docu/imgweb/diputados/511_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Planas Puchades, Luis ', 'Territorio': 'Diputado por ', 'Partido': 'G. P. ', 'url': '/docu/imgweb/diputados/512_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Iceta i Llorens, Miquel Octavi ', 'Territorio': 'Diputado por ', 'Partido': 'G. P. ', 'url': '/docu/imgweb/diputados/520_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Rodríguez Uribes, José Manuel ', 'Territorio': 'Diputado por ', 'Partido': 'G. P. ', 'url': '/docu/imgweb/diputados/506_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Duque Duque, Pedro ', 'Territorio': 'Diputado por ', 'Partido': 'G. P. ', 'url': '/docu/imgweb/diputados/513_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Escrivá Belmonte, José Luis ', 'Territorio': 'Diputado por ', 'Partido': 'G. P. ', 'url': '/docu/imgweb/diputados/508_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Castells Oliván, Manuel ', 'Territorio': 'Diputado por ', 'Partido': 'G. P. ', 'url': '/docu/imgweb/diputados/501_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Darias San Sebastián, Carolina ', 'Territorio': 'Diputado por ', 'Partido': 'G. P. ', 'url': '/docu/imgweb/diputados/516_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Lastra Fernández, Adriana ', 'Territorio': 'Diputada por Asturias', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/109_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Simancas Simancas, Rafael ', 'Territorio': 'Diputado por Madrid', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/287_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Fernández Casero, Ana Belén ', 'Territorio': 'Diputada por Cáceres', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/230_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Sicilia Alférez, Felipe Jesús ', 'Territorio': 'Diputado por Jaén', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/259_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Zaragoza Alonso, José ', 'Territorio': 'Diputado por Barcelona', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/196_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Ros Martínez, Susana ', 'Territorio': 'Diputada por Castellón/Castelló', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/53_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Meijón Couselo, Guillermo Antonio ', 'Territorio': 'Diputado por Pontevedra', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/1_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Carcedo Roces, María Luisa ', 'Territorio': 'Diputada por Asturias', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/270_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Valerio Cordero, Magdalena ', 'Territorio': 'Diputada por Guadalajara', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/140_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Gómez Hernández, Héctor ', 'Territorio': 'Diputado por S/C Tenerife', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/104_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Cerdán León, Santos ', 'Territorio': 'Diputado por Navarra', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/163_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Martínez Seijo, María Luz ', 'Territorio': 'Diputada por Palencia', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/251_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Leal Fernández, Isaura ', 'Territorio': 'Diputada por Madrid', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/352_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Sumelzo Jordán, Susana ', 'Territorio': 'Diputada por Zaragoza', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/126_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Elorza González, Odón ', 'Territorio': 'Diputado por Gipuzkoa', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/324_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'González Ramos, Manuel Gabriel ', 'Territorio': 'Diputado por Albacete', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/147_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Rodríguez Salas, José Antonio ', 'Territorio': 'Diputado por Granada', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/6_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Soler Mur, Alejandro ', 'Territorio': 'Diputado por Alicante/Alacant', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/144_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Faneca López, María Luisa ', 'Territorio': 'Diputada por Huelva', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/253_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Cancela Rodríguez, Pilar ', 'Territorio': 'Diputada por Coruña (A)', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/292_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'López Cano, Ignacio ', 'Territorio': 'Diputado por Málaga', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/343_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Gutiérrez Prieto, Sergio ', 'Territorio': 'Diputado por Toledo', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/180_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'López Álvarez, Patxi ', 'Territorio': 'Diputado por Bizkaia', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/61_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Casares Hontañón, Pedro ', 'Territorio': 'Diputado por Cantabria', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/347_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Diouf Dioh, Luc Andre ', 'Territorio': 'Diputado por Palmas (Las)', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/221_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Anguita Pérez, Omar ', 'Territorio': 'Diputado por Madrid', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/354_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Berja Vega, Laura ', 'Territorio': 'Diputada por Jaén', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/70_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Taibo Monelos, Diego ', 'Territorio': 'Diputado por Coruña (A)', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/373_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Cantera de Castro, Zaida ', 'Territorio': 'Diputada por Madrid', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/38_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Blanquer Alcaraz, Patricia ', 'Territorio': 'Diputada por Alicante/Alacant', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/71_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Serrada Pariente, David ', 'Territorio': 'Diputado por Salamanca', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/37_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Ruiz i Carbonell, Joan ', 'Territorio': 'Diputado por Tarragona', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/209_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Zamarrón Moreno, Agustín ', 'Territorio': 'Diputado por Burgos', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/19_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Nasarre Oliva, Begoña ', 'Territorio': 'Diputada por Huesca', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/313_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Carrillo de los Reyes, Beatriz Micaela ', 'Territorio': 'Diputada por Sevilla', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/280_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Botella Gómez, Ana María ', 'Territorio': 'Diputada por Valencia/València', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/238_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Marí Klose, Pau ', 'Territorio': 'Diputado por Zaragoza', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/73_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Fagúndez Campo, Antidio ', 'Territorio': 'Diputado por Zamora', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/4_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Caballero Gutiérrez, Helena ', 'Territorio': 'Diputada por Valladolid', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/320_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Alfonso Cendón, Javier ', 'Territorio': 'Diputado por León', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/103_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'García Gómez, Valentín ', 'Territorio': 'Diputado por Badajoz', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/226_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Andrés Barea, Josefa ', 'Territorio': 'Diputada por Valencia/València', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/66_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Aceves Galindo, José Luis ', 'Territorio': 'Diputado por Segovia', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/56_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Bueno Campanario, Eva Patricia ', 'Territorio': 'Diputada por Sevilla', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/314_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Peña Camarero, Esther ', 'Territorio': 'Diputada por Burgos', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/18_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Renau Martínez, Germán ', 'Territorio': 'Diputado por Castellón/Castelló', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/52_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Ramos Esteban, César Joaquín ', 'Territorio': 'Diputado por Cáceres', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/178_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Mínguez García, Montse ', 'Territorio': 'Diputada por Lleida', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/199_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Lamuà Estañol, Marc ', 'Territorio': 'Diputado por Girona', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/200_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Prieto Nieto, Ana ', 'Territorio': 'Diputada por Lugo', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/81_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Guerra López, Sonia ', 'Territorio': 'Diputada por Barcelona', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/357_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Sahuquillo García, Luis Carlos ', 'Territorio': 'Diputado por Cuenca', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/2_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Guijarro Ceballos, María ', 'Territorio': 'Diputada por Bizkaia', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/136_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Sánchez Jódar, Marisol ', 'Territorio': 'Diputada por Murcia', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/276_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Baños Ruiz, Carmen ', 'Territorio': 'Diputada por Murcia', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/365_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'García Morís, Roberto ', 'Territorio': 'Diputado por Asturias', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/231_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Alonso Suárez, María Olga ', 'Territorio': 'Diputada por Pontevedra', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/72_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Bravo Barco, Eva ', 'Territorio': 'Diputada por Cádiz', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/281_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Sancho Guardia, Alfredo ', 'Territorio': 'Diputado por Huesca', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/312_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Pérez Abellás, Adolfo ', 'Territorio': 'Diputado por Ourense', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/33_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Soto Burillo, Juan Luis ', 'Territorio': 'Diputado por Murcia', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/275_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Marra Domínguez, María Ángeles ', 'Territorio': 'Diputada por Pontevedra', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/46_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Navalpotro Gómez, Julio ', 'Territorio': 'Diputado por Madrid', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/366_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Vicente Viondi, Daniel ', 'Territorio': 'Diputado por Madrid', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/80_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Gutiérrez Salinas, Indalecio ', 'Territorio': 'Diputado por Almería', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/358_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Crespín Rubio, Rafaela ', 'Territorio': 'Diputada por Córdoba', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/107_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Serrano Martínez, Juan Francisco ', 'Territorio': 'Diputado por Jaén', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/158_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Baldoví Roda, Joan ', 'Territorio': 'Diputado por Valencia/València', 'Partido': 'G. P. Plural', 'url': '/docu/imgweb/diputados/247_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Sabanés Nadal, Inés ', 'Territorio': 'Diputada por Madrid', 'Partido': 'G. P. Plural', 'url': '/docu/imgweb/diputados/234_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Errejón Galván, Íñigo ', 'Territorio': 'Diputado por Madrid', 'Partido': 'G. P. Plural', 'url': '/docu/imgweb/diputados/233_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Perea i Conillas, María Mercè ', 'Territorio': 'Diputada por Barcelona', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/203_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Guinart Moreno, Lídia ', 'Territorio': 'Diputada por Barcelona', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/202_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'González Pérez, Ariagona ', 'Territorio': 'Diputada por Palmas (Las)', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/164_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Durán Peralta, José Carlos ', 'Territorio': 'Diputado por Málaga', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/342_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Ramón Utrabo, Elvira ', 'Territorio': 'Diputada por Granada', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/8_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Pons Sampietro, Pere Joan ', 'Territorio': 'Diputado por Balears (Illes)', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/223_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Sánchez Escobar, Mariano ', 'Territorio': 'Diputado por Badajoz', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/227_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Raya Rodríguez, María Tamara ', 'Territorio': 'Diputada por S/C Tenerife', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/112_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Ferrer Tesoro, Sonia ', 'Territorio': 'Diputada por Almería', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/114_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Villagrasa Quero, Noemí ', 'Territorio': 'Diputada por Zaragoza', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/49_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Ramos Rodríguez, José Luis ', 'Territorio': 'Diputado por Huelva', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/218_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Hurtado Zurera, Antonio ', 'Territorio': 'Diputado por Córdoba', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/372_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Narváez Bandera, María Dolores ', 'Territorio': 'Diputada por Málaga', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/154_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Bel Accensi, Ferran ', 'Territorio': 'Diputado por Tarragona', 'Partido': 'G. P. Plural', 'url': '/docu/imgweb/diputados/14_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Nogueras i Camero, Míriam ', 'Territorio': 'Diputada por Barcelona', 'Partido': 'G. P. Plural', 'url': '/docu/imgweb/diputados/27_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Borràs Castanyer, Laura ', 'Territorio': 'Diputada por Barcelona', 'Partido': 'G. P. Plural', 'url': '/docu/imgweb/diputados/25_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Ramírez Carner, Arnau ', 'Territorio': 'Diputado por Barcelona', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/197_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Aranda Vargas, Francisco ', 'Territorio': 'Diputado por Barcelona', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/198_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Andrés Añón, Carmen ', 'Territorio': 'Diputada por Barcelona', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/204_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Guaita Esteruelas, Sandra ', 'Territorio': 'Diputada por Tarragona', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/208_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'José Vélez, Rafael ', 'Territorio': 'Diputado por Madrid', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/361_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Del Valle de Iscar, Julio ', 'Territorio': 'Diputado por Valladolid', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/360_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Fernández Benéitez, Andrea ', 'Territorio': 'Diputada por León', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/102_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Antón Cacho, Javier ', 'Territorio': 'Diputado por Soria', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/100_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Arribas Maroto, Manuel ', 'Territorio': 'Diputado por Ávila', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/369_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Ortega Domínguez, José Ramón ', 'Territorio': 'Diputado por Cádiz', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/368_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Oria López, María Inmaculada ', 'Territorio': 'Diputada por Granada', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/370_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Losada Fernández, José ', 'Territorio': 'Diputado por Sevilla', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/353_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Lima Cid, Fuensanta ', 'Territorio': 'Diputada por Málaga', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/59_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Araujo Morales, Gemma ', 'Territorio': 'Diputada por Cádiz', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/364_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Rodríguez Gómez, María del Pilar ', 'Territorio': 'Diputada por Huelva', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/273_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Boadella Esteve, Genís ', 'Territorio': 'Diputado por Barcelona', 'Partido': 'G. P. Plural', 'url': '/docu/imgweb/diputados/24_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Alonso-Cuevillas i Sayrol, Jaume ', 'Territorio': 'Diputado por Barcelona', 'Partido': 'G. P. Plural', 'url': '/docu/imgweb/diputados/26_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Illamola Dausà, Mariona ', 'Territorio': 'Diputada por Girona', 'Partido': 'G. P. Plural', 'url': '/docu/imgweb/diputados/22_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Cañadell Salvia, Concep ', 'Territorio': 'Diputada por Lleida', 'Partido': 'G. P. Plural', 'url': '/docu/imgweb/diputados/21_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Miquel i Valentí, Sergi ', 'Territorio': 'Diputado por Girona', 'Partido': 'G. P. Plural', 'url': '/docu/imgweb/diputados/23_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Asens Llodrà, Jaume ', 'Territorio': 'Diputado por Barcelona', 'Partido': 'G. P. Confederal de Unidas Podemos-En Comú Podem-Galicia en Común', 'url': '/docu/imgweb/diputados/291_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Fernández Castañón, Sofía ', 'Territorio': 'Diputada por Asturias', 'Partido': 'G. P. Confederal de Unidas Podemos-En Comú Podem-Galicia en Común', 'url': '/docu/imgweb/diputados/272_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Santiago Romero, Enrique Fernando ', 'Territorio': 'Diputado por Madrid', 'Partido': 'G. P. Confederal de Unidas Podemos-En Comú Podem-Galicia en Común', 'url': '/docu/imgweb/diputados/45_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Gómez-Reino Varela, Antonio ', 'Territorio': 'Diputado por Coruña (A)', 'Partido': 'G. P. Confederal de Unidas Podemos-En Comú Podem-Galicia en Común', 'url': '/docu/imgweb/diputados/176_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Sagastizabal Unzetabarrenetxea, Idoia ', 'Territorio': 'Diputada por Bizkaia', 'Partido': 'G. P. Vasco (EAJ-PNV)', 'url': '/docu/imgweb/diputados/98_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Legarda Uriarte, Mikel ', 'Territorio': 'Diputado por Araba/Álava', 'Partido': 'G. P. Vasco (EAJ-PNV)', 'url': '/docu/imgweb/diputados/95_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Esteban Bravo, Aitor ', 'Territorio': 'Diputado por Bizkaia', 'Partido': 'G. P. Vasco (EAJ-PNV)', 'url': '/docu/imgweb/diputados/94_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Mayoral Perales, Rafael ', 'Territorio': 'Diputado por Madrid', 'Partido': 'G. P. Confederal de Unidas Podemos-En Comú Podem-Galicia en Común', 'url': '/docu/imgweb/diputados/336_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Rodríguez Rodríguez, Alberto ', 'Territorio': 'Diputado por S/C Tenerife', 'Partido': 'G. P. Confederal de Unidas Podemos-En Comú Podem-Galicia en Común', 'url': '/docu/imgweb/diputados/338_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Belarra Urteaga, Ione ', 'Territorio': 'Diputada por Navarra', 'Partido': 'G. P. Confederal de Unidas Podemos-En Comú Podem-Galicia en Común', 'url': '/docu/imgweb/diputados/139_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Vera Ruíz-Herrera, Noelia ', 'Territorio': 'Diputada por Cádiz', 'Partido': 'G. P. Confederal de Unidas Podemos-En Comú Podem-Galicia en Común', 'url': '/docu/imgweb/diputados/345_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Garrido Gutiérrez, Pilar ', 'Territorio': 'Diputada por Gipuzkoa', 'Partido': 'G. P. Confederal de Unidas Podemos-En Comú Podem-Galicia en Común', 'url': '/docu/imgweb/diputados/210_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'García Puig, María del Mar ', 'Territorio': 'Diputada por Barcelona', 'Partido': 'G. P. Confederal de Unidas Podemos-En Comú Podem-Galicia en Común', 'url': '/docu/imgweb/diputados/265_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Mena Arca, Joan ', 'Territorio': 'Diputado por Barcelona', 'Partido': 'G. P. Confederal de Unidas Podemos-En Comú Podem-Galicia en Común', 'url': '/docu/imgweb/diputados/264_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Gorospe Elezcano, Josune ', 'Territorio': 'Diputada por Bizkaia', 'Partido': 'G. P. Vasco (EAJ-PNV)', 'url': '/docu/imgweb/diputados/96_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Barandiaran Benito, Íñigo ', 'Territorio': 'Diputado por Gipuzkoa', 'Partido': 'G. P. Vasco (EAJ-PNV)', 'url': '/docu/imgweb/diputados/97_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Agirretxea Urresti, Joseba Andoni ', 'Territorio': 'Diputado por Gipuzkoa', 'Partido': 'G. P. Vasco (EAJ-PNV)', 'url': '/docu/imgweb/diputados/99_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Guijarro García, Txema ', 'Territorio': 'Diputado por Alicante/Alacant', 'Partido': 'G. P. Confederal de Unidas Podemos-En Comú Podem-Galicia en Común', 'url': '/docu/imgweb/diputados/344_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Pita Cárdenes, María del Carmen ', 'Territorio': 'Diputada por Palmas (Las)', 'Partido': 'G. P. Confederal de Unidas Podemos-En Comú Podem-Galicia en Común', 'url': '/docu/imgweb/diputados/356_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Maestro Moliner, Roser ', 'Territorio': 'Diputada por Valencia/València', 'Partido': 'G. P. Confederal de Unidas Podemos-En Comú Podem-Galicia en Común', 'url': '/docu/imgweb/diputados/282_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'López Domínguez, Laura ', 'Territorio': 'Diputada por Girona', 'Partido': 'G. P. Confederal de Unidas Podemos-En Comú Podem-Galicia en Común', 'url': '/docu/imgweb/diputados/263_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Cortés Gómez, Ismael ', 'Territorio': 'Diputado por Tarragona', 'Partido': 'G. P. Confederal de Unidas Podemos-En Comú Podem-Galicia en Común', 'url': '/docu/imgweb/diputados/350_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Vidal Sáez, Aina ', 'Territorio': 'Diputada por Barcelona', 'Partido': 'G. P. Confederal de Unidas Podemos-En Comú Podem-Galicia en Común', 'url': '/docu/imgweb/diputados/266_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Carvalho Dantas, María ', 'Territorio': 'Diputada por Barcelona', 'Partido': 'G. P. Republicano', 'url': '/docu/imgweb/diputados/190_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Eritja Ciuró, Francesc Xavier ', 'Territorio': 'Diputado por Lleida', 'Partido': 'G. P. Republicano', 'url': '/docu/imgweb/diputados/186_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Salvador i Duch, Jordi ', 'Territorio': 'Diputado por Tarragona', 'Partido': 'G. P. Republicano', 'url': '/docu/imgweb/diputados/184_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Bassa Coll, Montserrat ', 'Territorio': 'Diputada por Girona', 'Partido': 'G. P. Republicano', 'url': '/docu/imgweb/diputados/192_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Telechea i Lozano, Carolina ', 'Territorio': 'Diputada por Barcelona', 'Partido': 'G. P. Republicano', 'url': '/docu/imgweb/diputados/188_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Rufián Romero, Gabriel ', 'Territorio': 'Diputado por Barcelona', 'Partido': 'G. P. Republicano', 'url': '/docu/imgweb/diputados/187_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# ...
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Jiménez Linuesa, Beatriz ', 'Territorio': 'Diputada por Cuenca', 'Partido': 'G. P. Popular en el Congreso', 'url': '/docu/imgweb/diputados/206_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Lorite Lorite, Andrés ', 'Territorio': 'Diputado por Córdoba', 'Partido': 'G. P. Popular en el Congreso', 'url': '/docu/imgweb/diputados/105_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Píriz Maya, Víctor Valentín ', 'Territorio': 'Diputado por Badajoz', 'Partido': 'G. P. Popular en el Congreso', 'url': '/docu/imgweb/diputados/9_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'España Reina, Carolina ', 'Territorio': 'Diputada por Málaga', 'Partido': 'G. P. Popular en el Congreso', 'url': '/docu/imgweb/diputados/316_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Steegmann Olmedillas, Juan Luis ', 'Territorio': 'Diputado por Madrid', 'Partido': 'G. P. VOX', 'url': '/docu/imgweb/diputados/135_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Aizcorbe Torra, Juan José ', 'Territorio': 'Diputado por Barcelona', 'Partido': 'G. P. VOX', 'url': '/docu/imgweb/diputados/151_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Cañizares Pacheco, Inés María ', 'Territorio': 'Diputada por Toledo', 'Partido': 'G. P. VOX', 'url': '/docu/imgweb/diputados/152_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Gestoso de Miguel, Luis ', 'Territorio': 'Diputado por Murcia', 'Partido': 'G. P. VOX', 'url': '/docu/imgweb/diputados/131_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Alcaraz Martos, Francisco José ', 'Territorio': 'Diputado por Jaén', 'Partido': 'G. P. VOX', 'url': '/docu/imgweb/diputados/252_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Álvarez Fanjul, Beatriz ', 'Territorio': 'Diputada por Bizkaia', 'Partido': 'G. P. Popular en el Congreso', 'url': '/docu/imgweb/diputados/101_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Redondo Calvillo, María de la O ', 'Territorio': 'Diputada por Córdoba', 'Partido': 'G. P. Popular en el Congreso', 'url': '/docu/imgweb/diputados/106_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Postigo Quintana, Jesús ', 'Territorio': 'Diputado por Segovia', 'Partido': 'G. P. Popular en el Congreso', 'url': '/docu/imgweb/diputados/51_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Gamazo Micó, Óscar ', 'Territorio': 'Diputado por Valencia/València', 'Partido': 'G. P. Popular en el Congreso', 'url': '/docu/imgweb/diputados/212_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Cabezón Casas, Tomás ', 'Territorio': 'Diputado por Soria', 'Partido': 'G. P. Popular en el Congreso', 'url': '/docu/imgweb/diputados/28_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Gázquez Collado, Paloma ', 'Territorio': 'Diputada por Asturias', 'Partido': 'G. P. Popular en el Congreso', 'url': '/docu/imgweb/diputados/279_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Moro Almaraz, María Jesús ', 'Territorio': 'Diputada por Salamanca', 'Partido': 'G. P. Popular en el Congreso', 'url': '/docu/imgweb/diputados/91_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Navarro López, Pedro ', 'Territorio': 'Diputado por Zaragoza', 'Partido': 'G. P. Popular en el Congreso', 'url': '/docu/imgweb/diputados/220_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Velasco Morillo, Elvira ', 'Territorio': 'Diputada por Zamora', 'Partido': 'G. P. Popular en el Congreso', 'url': '/docu/imgweb/diputados/10_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Merino Martínez, Javier ', 'Territorio': 'Diputado por Rioja (La)', 'Partido': 'G. P. Popular en el Congreso', 'url': '/docu/imgweb/diputados/138_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Cruz-Guzmán García, María Soledad ', 'Territorio': 'Diputada por Sevilla', 'Partido': 'G. P. Popular en el Congreso', 'url': '/docu/imgweb/diputados/159_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'De Luna Tobarra, Llanos ', 'Territorio': 'Diputada por Barcelona', 'Partido': 'G. P. Popular en el Congreso', 'url': '/docu/imgweb/diputados/157_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'García Díez, Joaquín María ', 'Territorio': 'Diputado por Lugo', 'Partido': 'G. P. Popular en el Congreso', 'url': '/docu/imgweb/diputados/11_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Riolobos Regadera, Carmen ', 'Territorio': 'Diputada por Toledo', 'Partido': 'G. P. Popular en el Congreso', 'url': '/docu/imgweb/diputados/7_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Sancho Íñiguez, Herminio Rufino ', 'Territorio': 'Diputado por Teruel', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/15_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Tizón Vázquez, Uxía ', 'Territorio': 'Diputada por Ourense', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/374_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'García Chavarría, María Montserrat ', 'Territorio': 'Diputada por Coruña (A)', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/304_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Vilches Ruiz, María Luisa ', 'Territorio': 'Diputada por Albacete', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/332_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'González Caballero, Miguel Ángel ', 'Territorio': 'Diputado por Ciudad Real', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/222_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Canales Duque, Mariana de Gracia ', 'Territorio': 'Diputada por Cuenca', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/3_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Fuentes Curbelo, Juan Bernardo ', 'Territorio': 'Diputado por Palmas (Las)', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/359_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Cuatrecasas Asua, Juan ', 'Territorio': 'Diputado por Rioja (La)', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/303_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Cerqueiro González, Javier ', 'Territorio': 'Diputado por Lugo', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/47_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'García López, Maribel ', 'Territorio': 'Diputada por Badajoz', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/39_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Padilla Ruiz, Esther ', 'Territorio': 'Diputada por Toledo', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/173_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'López Zamora, Cristina ', 'Territorio': 'Diputada por Ciudad Real', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/224_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Senderos Oraá, Daniel ', 'Territorio': 'Diputado por Araba/Álava', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/367_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Pedraja Sáinz, Raquel ', 'Territorio': 'Diputada por Rioja (La)', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/362_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'López Somoza, Gema ', 'Territorio': 'Diputada por Madrid', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/363_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Azorín Salar, Lázaro ', 'Territorio': 'Diputado por Alicante/Alacant', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/371_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Seva Ruiz, Yolanda ', 'Territorio': 'Diputada por Alicante/Alacant', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/137_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Sarrià Morell, Vicent Manuel ', 'Territorio': 'Diputado por Valencia/València', 'Partido': 'G. P. Socialista', 'url': '/docu/imgweb/diputados/90_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Pérez Díaz, María Auxiliadora ', 'Territorio': 'Diputada por Palmas (Las)', 'Partido': 'G. P. Popular en el Congreso', 'url': '/docu/imgweb/diputados/160_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Callejas Cano, Juan Antonio ', 'Territorio': 'Diputado por Ciudad Real', 'Partido': 'G. P. Popular en el Congreso', 'url': '/docu/imgweb/diputados/35_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Carazo Hermoso, Eduardo ', 'Territorio': 'Diputado por Valladolid', 'Partido': 'G. P. Popular en el Congreso', 'url': '/docu/imgweb/diputados/245_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Alonso Pérez, José Ángel ', 'Territorio': 'Diputado por Valladolid', 'Partido': 'G. P. Popular en el Congreso', 'url': '/docu/imgweb/diputados/244_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Jiménez-Becerril Barrio, María Teresa ', 'Territorio': 'Diputada por Sevilla', 'Partido': 'G. P. Popular en el Congreso', 'url': '/docu/imgweb/diputados/179_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Paniagua Núñez, Miguel Ángel ', 'Territorio': 'Diputado por Palencia', 'Partido': 'G. P. Popular en el Congreso', 'url': '/docu/imgweb/diputados/240_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Ledesma Martín, Sebastián Jesús ', 'Territorio': 'Diputado por S/C Tenerife', 'Partido': 'G. P. Popular en el Congreso', 'url': '/docu/imgweb/diputados/110_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Castillo López, Elena ', 'Territorio': 'Diputada por Cantabria', 'Partido': 'G. P. Popular en el Congreso', 'url': '/docu/imgweb/diputados/77_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Bas Corugeira, Javier ', 'Territorio': 'Diputado por Pontevedra', 'Partido': 'G. P. Popular en el Congreso', 'url': '/docu/imgweb/diputados/118_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Jerez Juan, Miguel Ángel ', 'Territorio': 'Diputado por Balears (Illes)', 'Partido': 'G. P. Popular en el Congreso', 'url': '/docu/imgweb/diputados/124_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'García-Pelayo Jurado, María José ', 'Territorio': 'Diputada por Cádiz', 'Partido': 'G. P. Popular en el Congreso', 'url': '/docu/imgweb/diputados/17_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Romero Hernández, Carmelo ', 'Territorio': 'Diputado por Huelva', 'Partido': 'G. P. Popular en el Congreso', 'url': '/docu/imgweb/diputados/241_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Cortés Carballo, Mario ', 'Territorio': 'Diputado por Málaga', 'Partido': 'G. P. Popular en el Congreso', 'url': '/docu/imgweb/diputados/317_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.congreso.es/web/guest/hemiciclo>
# {'Nombre': 'Constenla Carbón, Juan Manuel ', 'Territorio': 'Diputado por Pontevedra', 'Partido': 'G. P. Popular en el Congreso', 'url': '/docu/imgweb/diputados/378_14.jpg'}
# 2021-02-08 09:20:51 [scrapy.core.engine] INFO: Closing spider (finished)
# 2021-02-08 09:20:51 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 254,
#  'downloader/request_count': 1,
#  'downloader/request_method_count/GET': 1,
#  'downloader/response_bytes': 40309,
#  'downloader/response_count': 1,
#  'downloader/response_status_count/200': 1,
#  'elapsed_time_seconds': 1.466237,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2021, 2, 8, 8, 20, 51, 789333),
#  'item_scraped_count': 365,
#  'log_count/DEBUG': 366,
#  'log_count/INFO': 10,
#  'response_received_count': 1,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2021, 2, 8, 8, 20, 50, 323096)}
# 2021-02-08 09:20:51 [scrapy.core.engine] INFO: Spider closed (finished)

# %% [markdown]
# ---

# %% [markdown]
# ### Optional Exercice

# %% [markdown]
# Open Notify has an [API](http://api.open-notify.org) that allows to request information about the humans living outside the Earth.
#
# Using this API, program a function that prints on screen the actual number of astronauts in the space, the number of tripulated ships in orbit and the name of every astronaut of each spacecraft.

# %%
import requests
import json


def SpaceCrafts():
    # Define url
    url = 'http://api.open-notify.org/astros.json'

    # Inizialize query
    response = requests.get(url)

    # Transform results to a dictionary
    content_dict = json.loads(response.content)
    print("Number of astronauts in orbit: %d" % content_dict["number"])
    naus = dict()

    for astro in content_dict['people']:
        if astro['craft'] in naus:
            naus[astro['craft']].append(astro['name'])
        else:
            naus[astro['craft']] = [astro['name']]
    print("Number of inhabited spacecrafts: %d" % len(naus.keys()))

    print("\nNumber of inhabitants of each craft:")
    for key, value in naus.items():
        print("   En la nau: %s (%d)" % (key, len(value)))
        [print("\t%s" % a) for a in value]

# %%
SpaceCrafts()
# Out:
# 2021-02-08 09:20:51 [urllib3.connectionpool] DEBUG: Starting new HTTP connection (1): api.open-notify.org:80
# 2021-02-08 09:20:52 [urllib3.connectionpool] DEBUG: http://api.open-notify.org:80 "GET /astros.json HTTP/1.1" 200 356
# Number of astronauts in orbit: 7
# Number of inhabited spacecrafts: 1
#
# Number of inhabitants of each craft:
#    En la nau: ISS (7)
# 	Sergey Ryzhikov
# 	Kate Rubins
# 	Sergey Kud-Sverchkov
# 	Mike Hopkins
# 	Victor Glover
# 	Shannon Walker
# 	Soichi Noguchi
